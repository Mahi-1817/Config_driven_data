# %%
# %sql
CREATE TABLE IF NOT EXISTS config_catalog.silver.sales
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS config_catalog.silver.customers
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS config_catalog.silver.inventory
USING DELTA;

# %%
# %sql
CREATE TABLE IF NOT EXISTS config_catalog.silver.products
USING DELTA;

# %%
# %sql
show grants on schema config_catalog.audit_tabales;

# %%
# %sql
grant all privileges
on schema config_catalog.audit_tabales
to `Admin`;
