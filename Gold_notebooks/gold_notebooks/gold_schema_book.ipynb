# %%
# %sql
CREATE SCHEMA IF NOT EXISTS config_catalog.gold;

# %%
# %sql
CREATE TABLE IF NOT EXISTS config_catalog.gold.dim_customers (
    customer_sk STRING,          -- surrogate key
    customer_id STRING,          -- business key
    name STRING,
    city STRING,
    email STRING,
    valid_from TIMESTAMP,
    valid_to TIMESTAMP,
    is_current BOOLEAN
)
USING DELTA;

# %%
# %sql
ALTER TABLE config_catalog.gold.dim_customers
SET TBLPROPERTIES (
  'delta.columnMapping.mode' = 'name'
);

# %%
# %sql
ALTER TABLE config_catalog.gold.dim_customers
RENAME COLUMN name TO customer_name;

# %%
# %sql
ALTER TABLE config_catalog.gold.dim_customers
RENAME COLUMN email TO last_updated;

# %%
# %sql
CREATE TABLE IF NOT EXISTS config_catalog.gold.dim_products (
    product_sk STRING,
    product_id STRING,
    product_name STRING,
    price DOUBLE,
    valid_from TIMESTAMP,
    valid_to TIMESTAMP,
    is_current BOOLEAN
)
USING DELTA;

# %%
# %sql
CREATE TABLE config_catalog.gold.fact_sales (
    order_id STRING,
    customer_sk STRING,
    product_sk STRING,
    amount string,
    order_date string
)
USING DELTA;

# %%
# %sql
DROP TABLE config_catalog.gold.fact_sales;

# %%
# %sql
delete from config_catalog.gold.fact_sales;
delete from config_catalog.gold.dim_customers;
delete from config_catalog.gold.dim_products;
delete from config_catalog.silver.customers;
delete from config_catalog.silver.products;
delete from config_catalog.silver.sales;
delete from config_catalog.silver.inventory;
delete from config_catalog.audit_tabales.dq_schema_null_audit;

# %%
# %sql
GRANT SELECT ON TABLE config_catalog.gold.dim_products TO `Admin`;
GRANT SELECT ON TABLE config_catalog.gold.dim_customers TO `Admin`;
GRANT SELECT ON TABLE config_catalog.gold.fact_sales TO `Admin`;
